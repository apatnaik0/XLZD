# %%
import pandas as pd
import numpy as np
import os, re
from pathlib import Path

def find_repo_root(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "PROJECT_EXPERIMENT_GUIDE.md").exists() and (candidate / "README.md").exists():
            return candidate
    raise RuntimeError("Could not find the XLZD repo root from the current working directory.")


REPO_ROOT = find_repo_root()

# %%
# Grab all files, radii, and heights
sim_path = REPO_ROOT.parent / "sim"
sim_data_path = sim_path / "simulation_data"
data_path = REPO_ROOT / "data"
entries = []
for file in sim_data_path.glob("R*H*F*.csv"):
    pattern = r"R(\d+)_H(\d+)_F(\d+)"
    match = re.search(pattern, str(file))

    if match:
        radius = match.group(1)
        height = match.group(2)
        fidelity = match.group(3)
        entries.append((file, int(radius), int(height), fidelity))

# %%
# Cut down the file
for entry in entries:
    file = entry[0]
    radius = entry[1]
    height = entry[2]
    fidelity = entry[3]
    
    data = pd.read_csv(file)
    data = data.copy()
    len_before = len(data)

    print("="*50)
    
    # Shift the z so its bottom-centered
    print(f"Minimum z of {min(data["sz"])}, adding {height} to z and sz")
    data["z"] = data["z"] + height
    data["sz"] = data["sz"] + height
    
    # Calculate radius and cut based on radius and height
    data.drop(data[np.sqrt(data["x"]**2 + data["y"]**2) > radius].index, inplace=True)
    data.drop(data[data["z"] > 2*height].index, inplace=True)
    data.drop(data[data["z"] < 0].index, inplace=True)
    #data.drop(data[data["ETPC"] > 3].index, inplace=True)
    data.drop(data[data["ETPC"] < 0.3].index, inplace=True)
    len_after = len(data)
    
    # Save the new dataframe
    new_file = data_path / f"{file.stem}_withcuts{file.suffix}"
    if os.path.exists(new_file):
        os.remove(new_file)
    data.to_csv(new_file, index=False)
    print(f"Dropped {round(((len_before - len_after) / len_before)*100, 2)}% events")
    print(f"Kept {len_after} events")
    print(f"File saved to {new_file}")
    print()

    # Add to file_manifest
    manifest_path = data_path / "file_manifest.csv"
    manifest = pd.read_csv(manifest_path)
    if new_file.name in manifest["filename"]:
        print(f"{new_file} already in manifest, passing")
        pass
    else:
        manifest.loc[len(manifest)] = [new_file.name, radius, height, height, fidelity]
        print(f"Wrote file {new_file.name} to manifest with radius {radius}, height {height}, z_center {height}, and fidelity {fidelity}")
    manifest.to_csv(manifest_path, index=False)
# Out:
# ==================================================
# Minimum z of -649.7648346038126, adding 106 to z and sz
# Dropped 99.76% events
# Kept 13190 events
# File saved to /home/pknauss/XLZD/data/R129_H106_F0_2447keVgamma_withcuts.csv
#
# Wrote file R129_H106_F0_2447keVgamma_withcuts.csv to manifest with radius 129, height 106, z_center 106, and fidelity 0
# ==================================================
# Minimum z of -688.2487800648252, adding 604 to z and sz
# Dropped 99.16% events
# Kept 9127 events
# File saved to /home/pknauss/XLZD/data/R1174_H604_F0_2447keVgamma_withcuts.csv
#
# Wrote file R1174_H604_F0_2447keVgamma_withcuts.csv to manifest with radius 1174, height 604, z_center 604, and fidelity 0
# ==================================================
# Minimum z of -1545.0, adding 1535 to z and sz
# Dropped 99.45% events
# Kept 11505 events
# File saved to /home/pknauss/XLZD/data/R535_H1535_F0_2447keVgamma_withcuts.csv
#
# Wrote file R535_H1535_F0_2447keVgamma_withcuts.csv to manifest with radius 535, height 1535, z_center 1535, and fidelity 0
# ==================================================
# Minimum z of -1959.0, adding 1949 to z and sz
# Dropped 98.82% events
# Kept 5452 events
# File saved to /home/pknauss/XLZD/data/R925_H1949_F0_2447keVgamma_withcuts.csv
#
# Wrote file R925_H1949_F0_2447keVgamma_withcuts.csv to manifest with radius 925, height 1949, z_center 1949, and fidelity 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/parsers.pyx:1067, in pandas._libs.parsers.TextReader._convert_tokens()
# -> 1067 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:1177, in pandas._libs.parsers.TextReader._convert_with_dtype()
# -> 1177 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:1837, in pandas._libs.parsers._try_int64()
# -> 1837 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Number is not int
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       4     radius = entry[1]
#       5     height = entry[2]
#       6     fidelity = entry[3]
#       7
# ----> 8     data = pd.read_csv(file)
#       9     data = data.copy()
#      10     len_before = len(data)
#      11
#
# File ~/xlzd/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/xlzd/lib/python3.14/site-packages/pandas/io/parsers/readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File ~/xlzd/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File ~/xlzd/lib/python3.14/site-packages/pandas/io/parsers/c_parser_wrapper.py:215, in CParserWrapper.read(self, nrows)
#     213 try:
#     214     if self.low_memory:
# --> 215         chunks = self._reader.read_low_memory(nrows)
#     216         # destructive to chunks
#     217         data = _concatenate_chunks(chunks, self.names)
#
# File pandas/_libs/parsers.pyx:832, in pandas._libs.parsers.TextReader.read_low_memory()
# --> 832 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:911, in pandas._libs.parsers.TextReader._read_rows()
# --> 911 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:1009, in pandas._libs.parsers.TextReader._convert_column_data()
# -> 1009 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:1070, in pandas._libs.parsers.TextReader._convert_tokens()
# -> 1070 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:
